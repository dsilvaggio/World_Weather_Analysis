# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_describe = city_weather["weather"][0]["description"] 
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_describe})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 1 | flinders
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 1 | baculin
# Processing Record 8 of Set 1 | bara
# Processing Record 9 of Set 1 | mandalgovi
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | qingdao
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | clyde river
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | erenhot
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | cobija
# Processing Record 20 of Set 1 | lagoa
# Processing Record 21 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 22 of Set 1 | chokurdakh
# Processing Record 23 of Set 1 | pizarro
# Processing Record 24 of Set 1 | tezu
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | rocha
# Processing Record 27 of Set 1 | methven
# Processing Record 28 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | wloclawek
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | kushiro
# Processing Record 34 of Set 1 | tungor
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 1 | mount isa
# Processing Record 41 of Set 1 | coihaique
# Processing Record 42 of Set 1 | aklavik
# Processing Record 43 of Set 1 | west bay
# Processing Record 44 of Set 1 | olga
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | pisco
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | douglas
# Processing Record 1 of Set 2 | shimoda
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | luganville
# Processing Record 9 of Set 2 | nyurba
# Processing Record 10 of Set 2 | umm lajj
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 2 | carmelo
# Processing Record 16 of Set 2 | aswan
# Processing Record 17 of Set 2 | lavrentiya
# Processing Record 18 of Set 2 | naze
# Processing Record 19 of Set 2 | mizdah
# Processing Record 20 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | forio
# Processing Record 26 of Set 2 | tocantinopolis
# City not found. Skipping...
# Processing Record 27 of Set 2 | saldanha
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | kampong cham
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | vila do maio
# Processing Record 33 of Set 2 | pevek
# Processing Record 34 of Set 2 | ketchikan
# Processing Record 35 of Set 2 | pen
# Processing Record 36 of Set 2 | zhangye
# Processing Record 37 of Set 2 | mbandaka
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | tazovskiy
# Processing Record 40 of Set 2 | talnakh
# Processing Record 41 of Set 2 | tamale
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | tirano
# Processing Record 44 of Set 2 | hasaki
# Processing Record 45 of Set 2 | keti bandar
# Processing Record 46 of Set 2 | hambantota
# Processing Record 47 of Set 2 | namatanai
# Processing Record 48 of Set 2 | torbay
# Processing Record 49 of Set 2 | pangai
# Processing Record 50 of Set 2 | hamilton
# Processing Record 1 of Set 3 | west wendover
# Processing Record 2 of Set 3 | fairbanks
# Processing Record 3 of Set 3 | nanortalik
# Processing Record 4 of Set 3 | lake city
# Processing Record 5 of Set 3 | geraldton
# Processing Record 6 of Set 3 | port elizabeth
# Processing Record 7 of Set 3 | mount gambier
# Processing Record 8 of Set 3 | byron bay
# Processing Record 9 of Set 3 | mwense
# Processing Record 10 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 3 | pakenham
# Processing Record 12 of Set 3 | leshukonskoye
# Processing Record 13 of Set 3 | daru
# Processing Record 14 of Set 3 | lorengau
# Processing Record 15 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 3 | jalpan
# Processing Record 17 of Set 3 | bandarbeyla
# Processing Record 18 of Set 3 | cootamundra
# Processing Record 19 of Set 3 | abha
# Processing Record 20 of Set 3 | carlisle
# Processing Record 21 of Set 3 | wad madani
# Processing Record 22 of Set 3 | husavik
# Processing Record 23 of Set 3 | ancud
# Processing Record 24 of Set 3 | vytegra
# Processing Record 25 of Set 3 | icod de los vinos
# Processing Record 26 of Set 3 | fare
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | zhigansk
# Processing Record 29 of Set 3 | obihiro
# Processing Record 30 of Set 3 | algiers
# Processing Record 31 of Set 3 | pauini
# Processing Record 32 of Set 3 | ballina
# Processing Record 33 of Set 3 | rio grande
# Processing Record 34 of Set 3 | avarua
# Processing Record 35 of Set 3 | san patricio
# Processing Record 36 of Set 3 | mayo
# Processing Record 37 of Set 3 | yashan
# Processing Record 38 of Set 3 | butaritari
# Processing Record 39 of Set 3 | alice springs
# Processing Record 40 of Set 3 | buraydah
# Processing Record 41 of Set 3 | strangnas
# Processing Record 42 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | itaituba
# Processing Record 45 of Set 3 | sinop
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | sao felix do xingu
# Processing Record 48 of Set 3 | springfield
# Processing Record 49 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | pishva
# Processing Record 1 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 4 | gilgit
# Processing Record 3 of Set 4 | norman wells
# Processing Record 4 of Set 4 | kaeo
# Processing Record 5 of Set 4 | richards bay
# Processing Record 6 of Set 4 | salalah
# Processing Record 7 of Set 4 | pangnirtung
# Processing Record 8 of Set 4 | tiksi
# Processing Record 9 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 4 | falam
# Processing Record 11 of Set 4 | broken hill
# Processing Record 12 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 13 of Set 4 | limbang
# Processing Record 14 of Set 4 | portland
# Processing Record 15 of Set 4 | cape town
# Processing Record 16 of Set 4 | viedma
# Processing Record 17 of Set 4 | mahanoro
# Processing Record 18 of Set 4 | kimbe
# Processing Record 19 of Set 4 | port augusta
# Processing Record 20 of Set 4 | buchanan
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | alofi
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | navrongo
# Processing Record 25 of Set 4 | yellowknife
# Processing Record 26 of Set 4 | cayenne
# Processing Record 27 of Set 4 | hvammstangi
# City not found. Skipping...
# Processing Record 28 of Set 4 | palmeira das missoes
# Processing Record 29 of Set 4 | puerto baquerizo moreno
# Processing Record 30 of Set 4 | dong hoi
# Processing Record 31 of Set 4 | kapuskasing
# Processing Record 32 of Set 4 | anadyr
# Processing Record 33 of Set 4 | bridlington
# Processing Record 34 of Set 4 | eureka
# Processing Record 35 of Set 4 | sola
# Processing Record 36 of Set 4 | vysokogornyy
# Processing Record 37 of Set 4 | ugoofaaru
# Processing Record 38 of Set 4 | mingguang
# Processing Record 39 of Set 4 | udachnyy
# Processing Record 40 of Set 4 | falun
# Processing Record 41 of Set 4 | severo-kurilsk
# Processing Record 42 of Set 4 | kaitangata
# Processing Record 43 of Set 4 | noumea
# Processing Record 44 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 45 of Set 4 | te anau
# Processing Record 46 of Set 4 | malakal
# Processing Record 47 of Set 4 | bambanglipuro
# Processing Record 48 of Set 4 | atuona
# Processing Record 49 of Set 4 | talaya
# Processing Record 50 of Set 4 | santa cruz
# Processing Record 1 of Set 5 | havoysund
# Processing Record 2 of Set 5 | bondoukou
# Processing Record 3 of Set 5 | varhaug
# Processing Record 4 of Set 5 | harper
# Processing Record 5 of Set 5 | caravelas
# Processing Record 6 of Set 5 | tegucigalpa
# Processing Record 7 of Set 5 | visavadar
# Processing Record 8 of Set 5 | port blair
# Processing Record 9 of Set 5 | touros
# Processing Record 10 of Set 5 | college
# Processing Record 11 of Set 5 | isangel
# Processing Record 12 of Set 5 | helong
# Processing Record 13 of Set 5 | qarqin
# Processing Record 14 of Set 5 | okha
# Processing Record 15 of Set 5 | carbonear
# Processing Record 16 of Set 5 | katangli
# Processing Record 17 of Set 5 | de-kastri
# Processing Record 18 of Set 5 | maniitsoq
# Processing Record 19 of Set 5 | svetlyy
# Processing Record 20 of Set 5 | polyarnyy
# Processing Record 21 of Set 5 | zabol
# Processing Record 22 of Set 5 | cherskiy
# Processing Record 23 of Set 5 | mnogovershinnyy
# Processing Record 24 of Set 5 | shubarkuduk
# Processing Record 25 of Set 5 | qaanaaq
# Processing Record 26 of Set 5 | ornskoldsvik
# Processing Record 27 of Set 5 | dunmore east
# Processing Record 28 of Set 5 | bismarck
# Processing Record 29 of Set 5 | klaksvik
# Processing Record 30 of Set 5 | chifeng
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 5 | douentza
# Processing Record 34 of Set 5 | kayerkan
# Processing Record 35 of Set 5 | chengdu
# Processing Record 36 of Set 5 | bulungu
# Processing Record 37 of Set 5 | thinadhoo
# Processing Record 38 of Set 5 | sungaipenuh
# Processing Record 39 of Set 5 | faanui
# Processing Record 40 of Set 5 | bethel
# Processing Record 41 of Set 5 | buala
# Processing Record 42 of Set 5 | columbus
# Processing Record 43 of Set 5 | port hardy
# Processing Record 44 of Set 5 | nizhniy tsasuchey
# Processing Record 45 of Set 5 | yumen
# Processing Record 46 of Set 5 | esterhazy
# Processing Record 47 of Set 5 | solhan
# Processing Record 48 of Set 5 | mahanje
# Processing Record 49 of Set 5 | daloa
# Processing Record 50 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 6 | tabulbah
# City not found. Skipping...
# Processing Record 2 of Set 6 | camacha
# Processing Record 3 of Set 6 | narsaq
# Processing Record 4 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 6 | soderhamn
# Processing Record 6 of Set 6 | deputatskiy
# Processing Record 7 of Set 6 | sechura
# Processing Record 8 of Set 6 | kavieng
# Processing Record 9 of Set 6 | vila
# Processing Record 10 of Set 6 | altagracia de orituco
# Processing Record 11 of Set 6 | baykit
# Processing Record 12 of Set 6 | saint-georges
# Processing Record 13 of Set 6 | beatrice
# Processing Record 14 of Set 6 | saint george
# Processing Record 15 of Set 6 | batagay-alyta
# Processing Record 16 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 17 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 6 | dunedin
# Processing Record 19 of Set 6 | jaumave
# Processing Record 20 of Set 6 | avallon
# Processing Record 21 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 6 | ville-marie
# Processing Record 23 of Set 6 | ostersund
# Processing Record 24 of Set 6 | komsomolskiy
# Processing Record 25 of Set 6 | chunskiy
# Processing Record 26 of Set 6 | meulaboh
# Processing Record 27 of Set 6 | chuy
# Processing Record 28 of Set 6 | murray bridge
# Processing Record 29 of Set 6 | sheopur
# Processing Record 30 of Set 6 | teacapan
# Processing Record 31 of Set 6 | marsh harbour
# Processing Record 32 of Set 6 | chengde
# Processing Record 33 of Set 6 | kinablangan
# Processing Record 34 of Set 6 | reyes
# Processing Record 35 of Set 6 | san cristobal
# Processing Record 36 of Set 6 | faya
# Processing Record 37 of Set 6 | kangaatsiaq
# Processing Record 38 of Set 6 | bonthe
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | wanning
# Processing Record 41 of Set 6 | palmer
# Processing Record 42 of Set 6 | paita
# Processing Record 43 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 44 of Set 6 | new norfolk
# Processing Record 45 of Set 6 | gannavaram
# Processing Record 46 of Set 6 | bathsheba
# Processing Record 47 of Set 6 | villazon
# Processing Record 48 of Set 6 | hithadhoo
# Processing Record 49 of Set 6 | russkaya polyana
# Processing Record 50 of Set 6 | saint-francois
# Processing Record 1 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 2 of Set 7 | esperance
# Processing Record 3 of Set 7 | high level
# Processing Record 4 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 7 | hay river
# Processing Record 6 of Set 7 | lugo
# Processing Record 7 of Set 7 | boulder
# Processing Record 8 of Set 7 | dingle
# Processing Record 9 of Set 7 | prince rupert
# Processing Record 10 of Set 7 | conceicao do araguaia
# Processing Record 11 of Set 7 | gopalur
# Processing Record 12 of Set 7 | george
# Processing Record 13 of Set 7 | manzhouli
# Processing Record 14 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 7 | carutapera
# Processing Record 16 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 7 | ayan
# Processing Record 18 of Set 7 | acapulco
# Processing Record 19 of Set 7 | merauke
# Processing Record 20 of Set 7 | prince george
# Processing Record 21 of Set 7 | ponta do sol
# Processing Record 22 of Set 7 | porto uniao
# Processing Record 23 of Set 7 | yulara
# Processing Record 24 of Set 7 | alcudia
# Processing Record 25 of Set 7 | belyy yar
# Processing Record 26 of Set 7 | trincomalee
# Processing Record 27 of Set 7 | sao joao da barra
# Processing Record 28 of Set 7 | jieznas
# Processing Record 29 of Set 7 | novaci
# Processing Record 30 of Set 7 | rovaniemi
# Processing Record 31 of Set 7 | lucapa
# Processing Record 32 of Set 7 | krasnovishersk
# Processing Record 33 of Set 7 | sharjah
# Processing Record 34 of Set 7 | codrington
# Processing Record 35 of Set 7 | mayakonda
# Processing Record 36 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 7 | sibolga
# Processing Record 38 of Set 7 | vila franca do campo
# Processing Record 39 of Set 7 | cambrils
# Processing Record 40 of Set 7 | skjervoy
# Processing Record 41 of Set 7 | kirakira
# Processing Record 42 of Set 7 | ahipara
# Processing Record 43 of Set 7 | idanre
# Processing Record 44 of Set 7 | pemberton
# Processing Record 45 of Set 7 | inirida
# Processing Record 46 of Set 7 | nambucca heads
# Processing Record 47 of Set 7 | capitao poco
# Processing Record 48 of Set 7 | nortelandia
# Processing Record 49 of Set 7 | turkistan
# Processing Record 50 of Set 7 | capitan bado
# Processing Record 1 of Set 8 | castro
# Processing Record 2 of Set 8 | hami
# Processing Record 3 of Set 8 | tuktoyaktuk
# Processing Record 4 of Set 8 | okhotsk
# Processing Record 5 of Set 8 | grand gaube
# Processing Record 6 of Set 8 | pacific grove
# Processing Record 7 of Set 8 | penzance
# Processing Record 8 of Set 8 | victor harbor
# Processing Record 9 of Set 8 | pleasanton
# Processing Record 10 of Set 8 | miahuatlan
# Processing Record 11 of Set 8 | kungurtug
# Processing Record 12 of Set 8 | kahului
# Processing Record 13 of Set 8 | ahuimanu
# Processing Record 14 of Set 8 | phangnga
# Processing Record 15 of Set 8 | kodiak
# Processing Record 16 of Set 8 | waipawa
# Processing Record 17 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 8 | armidale
# Processing Record 19 of Set 8 | loreto
# Processing Record 20 of Set 8 | marfino
# Processing Record 21 of Set 8 | vila velha
# Processing Record 22 of Set 8 | egvekinot
# Processing Record 23 of Set 8 | vagay
# Processing Record 24 of Set 8 | eyl
# Processing Record 25 of Set 8 | fort nelson
# Processing Record 26 of Set 8 | rawson
# Processing Record 27 of Set 8 | sonoita
# Processing Record 28 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 29 of Set 8 | wakkanai
# Processing Record 30 of Set 8 | bucerias
# Processing Record 31 of Set 8 | yerbogachen
# Processing Record 32 of Set 8 | adrar
# Processing Record 33 of Set 8 | mount darwin
# Processing Record 34 of Set 8 | pacifica
# Processing Record 35 of Set 8 | verkhniye tatyshly
# Processing Record 36 of Set 8 | dunayivtsi
# City not found. Skipping...
# Processing Record 37 of Set 8 | cabo san lucas
# Processing Record 38 of Set 8 | lasa
# Processing Record 39 of Set 8 | novoagansk
# Processing Record 40 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 8 | tsiroanomandidy
# Processing Record 42 of Set 8 | khani
# Processing Record 43 of Set 8 | vao
# Processing Record 44 of Set 8 | asayita
# City not found. Skipping...
# Processing Record 45 of Set 8 | san andres
# Processing Record 46 of Set 8 | zyukayka
# Processing Record 47 of Set 8 | sitka
# Processing Record 48 of Set 8 | port-gentil
# Processing Record 49 of Set 8 | oktyabrskiy
# Processing Record 50 of Set 8 | tual
# Processing Record 1 of Set 9 | iqaluit
# Processing Record 2 of Set 9 | batemans bay
# Processing Record 3 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 9 | leningradskiy
# Processing Record 5 of Set 9 | mareeba
# Processing Record 6 of Set 9 | slave lake
# Processing Record 7 of Set 9 | chernyshevskiy
# Processing Record 8 of Set 9 | kloulklubed
# Processing Record 9 of Set 9 | kabare
# Processing Record 10 of Set 9 | seoul
# Processing Record 11 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 12 of Set 9 | nantucket
# Processing Record 13 of Set 9 | wanaka
# Processing Record 14 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 9 | cordoba
# Processing Record 16 of Set 9 | pitsunda
# Processing Record 17 of Set 9 | tahe
# Processing Record 18 of Set 9 | george town
# Processing Record 19 of Set 9 | vestmannaeyjar
# Processing Record 20 of Set 9 | ulaangom
# Processing Record 21 of Set 9 | naryan-mar
# Processing Record 22 of Set 9 | sinnar
# Processing Record 23 of Set 9 | roebourne
# Processing Record 24 of Set 9 | eslov
# Processing Record 25 of Set 9 | phan thiet
# Processing Record 26 of Set 9 | lazaro cardenas
# Processing Record 27 of Set 9 | ust-kuyga
# Processing Record 28 of Set 9 | port lincoln
# Processing Record 29 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 9 | lisala
# Processing Record 31 of Set 9 | pilar
# Processing Record 32 of Set 9 | nabire
# Processing Record 33 of Set 9 | laguna
# Processing Record 34 of Set 9 | kavaratti
# Processing Record 35 of Set 9 | devonport
# Processing Record 36 of Set 9 | geylegphug
# City not found. Skipping...
# Processing Record 37 of Set 9 | kautokeino
# Processing Record 38 of Set 9 | glenwood springs
# Processing Record 39 of Set 9 | tazmalt
# Processing Record 40 of Set 9 | port hawkesbury
# Processing Record 41 of Set 9 | zemio
# Processing Record 42 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 9 | lompoc
# Processing Record 44 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 45 of Set 9 | warri
# Processing Record 46 of Set 9 | lata
# Processing Record 47 of Set 9 | sao filipe
# Processing Record 48 of Set 9 | agirish
# Processing Record 49 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 9 | lubango
# Processing Record 1 of Set 10 | shahreza
# Processing Record 2 of Set 10 | insar
# Processing Record 3 of Set 10 | puerto madryn
# Processing Record 4 of Set 10 | agadez
# Processing Record 5 of Set 10 | evensk
# Processing Record 6 of Set 10 | ginda
# Processing Record 7 of Set 10 | miri
# Processing Record 8 of Set 10 | requena
# Processing Record 9 of Set 10 | bud
# Processing Record 10 of Set 10 | marovoay
# Processing Record 11 of Set 10 | bulawayo
# Processing Record 12 of Set 10 | odda
# Processing Record 13 of Set 10 | bambous virieux
# Processing Record 14 of Set 10 | jatai
# Processing Record 15 of Set 10 | bozuyuk
# Processing Record 16 of Set 10 | marzuq
# Processing Record 17 of Set 10 | arrecife
# Processing Record 18 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 10 | tir pol
# City not found. Skipping...
# Processing Record 20 of Set 10 | sorland
# Processing Record 21 of Set 10 | gazanjyk
# Processing Record 22 of Set 10 | xique-xique
# Processing Record 23 of Set 10 | khandyga
# Processing Record 24 of Set 10 | voh
# Processing Record 25 of Set 10 | jalu
# Processing Record 26 of Set 10 | kodinsk
# Processing Record 27 of Set 10 | tamiahua
# Processing Record 28 of Set 10 | pangody
# Processing Record 29 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 10 | lake charles
# Processing Record 31 of Set 10 | el carrizo
# Processing Record 32 of Set 10 | ongandjera
# Processing Record 33 of Set 10 | fortuna
# Processing Record 34 of Set 10 | burnie
# Processing Record 35 of Set 10 | balabac
# Processing Record 36 of Set 10 | olinda
# Processing Record 37 of Set 10 | skibbereen
# Processing Record 38 of Set 10 | kovylkino
# Processing Record 39 of Set 10 | moussoro
# Processing Record 40 of Set 10 | sayanskiy
# City not found. Skipping...
# Processing Record 41 of Set 10 | kulhudhuffushi
# Processing Record 42 of Set 10 | amazar
# Processing Record 43 of Set 10 | sur
# Processing Record 44 of Set 10 | la ronge
# Processing Record 45 of Set 10 | verkh-usugli
# Processing Record 46 of Set 10 | svetlogorsk
# Processing Record 47 of Set 10 | mitsamiouli
# Processing Record 48 of Set 10 | sault sainte marie
# Processing Record 49 of Set 10 | cockburn town
# Processing Record 50 of Set 10 | gazojak
# Processing Record 1 of Set 11 | kruisfontein
# Processing Record 2 of Set 11 | mooi river
# City not found. Skipping...
# Processing Record 3 of Set 11 | ler
# Processing Record 4 of Set 11 | corralillo
# Processing Record 5 of Set 11 | eenhana
# Processing Record 6 of Set 11 | port shepstone
# Processing Record 7 of Set 11 | korla
# Processing Record 8 of Set 11 | san jose
# Processing Record 9 of Set 11 | necochea
# Processing Record 10 of Set 11 | faro
# Processing Record 11 of Set 11 | kuytun
# Processing Record 12 of Set 11 | saint-pierre
# Processing Record 13 of Set 11 | sorong
# Processing Record 14 of Set 11 | sinazongwe
# Processing Record 15 of Set 11 | northam
# Processing Record 16 of Set 11 | dobryanka
# Processing Record 17 of Set 11 | montmagny
# Processing Record 18 of Set 11 | kenai
# Processing Record 19 of Set 11 | batticaloa
# Processing Record 20 of Set 11 | kudahuvadhoo
# Processing Record 21 of Set 11 | itarema
# Processing Record 22 of Set 11 | dicabisagan
# Processing Record 23 of Set 11 | zhuhai
# Processing Record 24 of Set 11 | bandikui
# Processing Record 25 of Set 11 | kieta
# Processing Record 26 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 11 | warr acres
# Processing Record 28 of Set 11 | tygda
# Processing Record 29 of Set 11 | chara
# Processing Record 30 of Set 11 | namibe
# Processing Record 31 of Set 11 | nome
# Processing Record 32 of Set 11 | doha
# Processing Record 33 of Set 11 | lapua
# Processing Record 34 of Set 11 | churapcha
# Processing Record 35 of Set 11 | kununurra
# Processing Record 36 of Set 11 | baiyin
# Processing Record 37 of Set 11 | aykhal
# Processing Record 38 of Set 11 | rio gallegos
# Processing Record 39 of Set 11 | grand-santi
# Processing Record 40 of Set 11 | prado
# Processing Record 41 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 11 | bafoulabe
# Processing Record 43 of Set 11 | sydney
# Processing Record 44 of Set 11 | tonantins
# Processing Record 45 of Set 11 | santa maria
# Processing Record 46 of Set 11 | veraval
# Processing Record 47 of Set 11 | ryotsu
# Processing Record 48 of Set 11 | mizpe ramon
# City not found. Skipping...
# Processing Record 49 of Set 11 | airai
# Processing Record 50 of Set 11 | chilca
# Processing Record 1 of Set 12 | novomykolayivka
# Processing Record 2 of Set 12 | esil
# Processing Record 3 of Set 12 | ola
# Processing Record 4 of Set 12 | katsuura
# Processing Record 5 of Set 12 | tautira
# Processing Record 6 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 7 of Set 12 | sturgeon falls
# Processing Record 8 of Set 12 | pingliang
# Processing Record 9 of Set 12 | mabaruma
# Processing Record 10 of Set 12 | mbanza-ngungu
# Processing Record 11 of Set 12 | grao mogol
# Processing Record 12 of Set 12 | tessalit
# Processing Record 13 of Set 12 | santa cruz de la palma
# Processing Record 14 of Set 12 | porto velho
# Processing Record 15 of Set 12 | fray bentos
# Processing Record 16 of Set 12 | tadine
# Processing Record 17 of Set 12 | san ramon
# Processing Record 18 of Set 12 | lom sak
# Processing Record 19 of Set 12 | marawi
# Processing Record 20 of Set 12 | mezen
# Processing Record 21 of Set 12 | gimli
# Processing Record 22 of Set 12 | padang
# Processing Record 23 of Set 12 | kimparana
# Processing Record 24 of Set 12 | tiarei
# Processing Record 25 of Set 12 | osmena
# Processing Record 26 of Set 12 | sivaki
# Processing Record 27 of Set 12 | heidelberg
# Processing Record 28 of Set 12 | yar-sale
# Processing Record 29 of Set 12 | palana
# Processing Record 30 of Set 12 | tangshan
# Processing Record 31 of Set 12 | hamamatsu
# Processing Record 32 of Set 12 | bilibino
# Processing Record 33 of Set 12 | bardiyah
# Processing Record 34 of Set 12 | araouane
# Processing Record 35 of Set 12 | hagi
# Processing Record 36 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 37 of Set 12 | funadhoo
# Processing Record 38 of Set 12 | broome
# Processing Record 39 of Set 12 | siniscola
# Processing Record 40 of Set 12 | muscat
# Processing Record 41 of Set 12 | batagay
# Processing Record 42 of Set 12 | meiganga
# Processing Record 43 of Set 12 | kandrian
# Processing Record 44 of Set 12 | brae
# Processing Record 45 of Set 12 | borogontsy
# Processing Record 46 of Set 12 | abu dhabi
# Processing Record 47 of Set 12 | puerto escondido
# Processing Record 48 of Set 12 | lapi
# Processing Record 49 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 50 of Set 12 | dongying
# Processing Record 1 of Set 13 | tomigusuku
# Processing Record 2 of Set 13 | coquimbo
# Processing Record 3 of Set 13 | verkhnyaya inta
# Processing Record 4 of Set 13 | kualakapuas
# Processing Record 5 of Set 13 | vanimo
# Processing Record 6 of Set 13 | nicoya
# Processing Record 7 of Set 13 | potgietersrus
# City not found. Skipping...
# Processing Record 8 of Set 13 | arequipa
# Processing Record 9 of Set 13 | the valley
# Processing Record 10 of Set 13 | bom jesus
# Processing Record 11 of Set 13 | tyler
# Processing Record 12 of Set 13 | sakakah
# Processing Record 13 of Set 13 | izvestkovyy
# Processing Record 14 of Set 13 | sheregesh
# Processing Record 15 of Set 13 | sao paulo de olivenca
# Processing Record 16 of Set 13 | matagami
# Processing Record 17 of Set 13 | vardo
# Processing Record 18 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 13 | plettenberg bay
# Processing Record 20 of Set 13 | marsaxlokk
# Processing Record 21 of Set 13 | peleduy
# Processing Record 22 of Set 13 | zarand
# Processing Record 23 of Set 13 | dawei
# Processing Record 24 of Set 13 | voznesenye
# Processing Record 25 of Set 13 | catanduva
# Processing Record 26 of Set 13 | asau
# Processing Record 27 of Set 13 | manado
# Processing Record 28 of Set 13 | redlands
# Processing Record 29 of Set 13 | kasongo
# Processing Record 30 of Set 13 | grindavik
# Processing Record 31 of Set 13 | yaan
# Processing Record 32 of Set 13 | ossora
# Processing Record 33 of Set 13 | cassilandia
# Processing Record 34 of Set 13 | kargopol
# Processing Record 35 of Set 13 | luderitz
# Processing Record 36 of Set 13 | san martin
# Processing Record 37 of Set 13 | makakilo city
# Processing Record 38 of Set 13 | bonavista
# Processing Record 39 of Set 13 | dodge city
# Processing Record 40 of Set 13 | walvis bay
# Processing Record 41 of Set 13 | manggar
# Processing Record 42 of Set 13 | hofn
# Processing Record 43 of Set 13 | kuito
# Processing Record 44 of Set 13 | iisalmi
# Processing Record 45 of Set 13 | altay
# Processing Record 46 of Set 13 | samana
# Processing Record 47 of Set 13 | winnemucca
# Processing Record 48 of Set 13 | olafsvik
# Processing Record 49 of Set 13 | aitape
# Processing Record 50 of Set 13 | shingu
# Processing Record 1 of Set 14 | sabha
# Processing Record 2 of Set 14 | jiexiu
# Processing Record 3 of Set 14 | kendari
# Processing Record 4 of Set 14 | ekhabi
# Processing Record 5 of Set 14 | halifax
# Processing Record 6 of Set 14 | natal
# Processing Record 7 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 8 of Set 14 | lyuban
# Processing Record 9 of Set 14 | santa marta
# Processing Record 10 of Set 14 | mandurah
# Processing Record 11 of Set 14 | mae sai
# Processing Record 12 of Set 14 | goteborg
# City not found. Skipping...
# Processing Record 13 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 14 | tumaco
# Processing Record 15 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 14 | belmonte
# Processing Record 17 of Set 14 | haines junction
# Processing Record 18 of Set 14 | machali
# Processing Record 19 of Set 14 | mbumi
# Processing Record 20 of Set 14 | joensuu
# Processing Record 21 of Set 14 | taoudenni
# Processing Record 22 of Set 14 | aguimes
# Processing Record 23 of Set 14 | north bend
# Processing Record 24 of Set 14 | sept-iles
# Processing Record 25 of Set 14 | senno
# Processing Record 26 of Set 14 | marathopolis
# City not found. Skipping...
# Processing Record 27 of Set 14 | saint-augustin
# Processing Record 28 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 14 | vryburg
# Processing Record 30 of Set 14 | pocone
# Processing Record 31 of Set 14 | axim
# Processing Record 32 of Set 14 | xam nua
# Processing Record 33 of Set 14 | maceio
# Processing Record 34 of Set 14 | sapa
# Processing Record 35 of Set 14 | eden
# Processing Record 36 of Set 14 | port hedland
# Processing Record 37 of Set 14 | melfort
# Processing Record 38 of Set 14 | hobyo
# Processing Record 39 of Set 14 | muli
# Processing Record 40 of Set 14 | nizhniy odes
# Processing Record 41 of Set 14 | dayong
# Processing Record 42 of Set 14 | kpandae
# Processing Record 43 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 14 | la libertad
# Processing Record 45 of Set 14 | brokopondo
# Processing Record 46 of Set 14 | batangafo
# Processing Record 47 of Set 14 | aripuana
# Processing Record 48 of Set 14 | poso
# Processing Record 49 of Set 14 | puchezh
# Processing Record 50 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 15 | bafq
# Processing Record 2 of Set 15 | samarai
# Processing Record 3 of Set 15 | along
# Processing Record 4 of Set 15 | barhi
# Processing Record 5 of Set 15 | troitskoye
# Processing Record 6 of Set 15 | muisne
# Processing Record 7 of Set 15 | karratha
# Processing Record 8 of Set 15 | coracora
# Processing Record 9 of Set 15 | roma
# Processing Record 10 of Set 15 | cabildo
# Processing Record 11 of Set 15 | ust-nera
# Processing Record 12 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 13 of Set 15 | king city
# Processing Record 14 of Set 15 | labuan
# Processing Record 15 of Set 15 | imeni poliny osipenko
# Processing Record 16 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 15 | san vicente
# Processing Record 18 of Set 15 | kailua
# Processing Record 19 of Set 15 | shihezi
# Processing Record 20 of Set 15 | camajuani
# Processing Record 21 of Set 15 | mozelos
# Processing Record 22 of Set 15 | borlange
# City not found. Skipping...
# Processing Record 23 of Set 15 | panama city
# Processing Record 24 of Set 15 | yakima
# Processing Record 25 of Set 15 | sangar
# Processing Record 26 of Set 15 | chadiza
# Processing Record 27 of Set 15 | pasighat
# Processing Record 28 of Set 15 | coos bay
# Processing Record 29 of Set 15 | esteli
# Processing Record 30 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 15 | copperas cove
# Processing Record 32 of Set 15 | kirovskiy
# Processing Record 33 of Set 15 | longjiang
# Processing Record 34 of Set 15 | visby
# Processing Record 35 of Set 15 | khasan
# Processing Record 36 of Set 15 | terrace
# Processing Record 37 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 15 | dali
# Processing Record 39 of Set 15 | muros
# Processing Record 40 of Set 15 | sabang
# Processing Record 41 of Set 15 | sulur
# Processing Record 42 of Set 15 | paamiut
# Processing Record 43 of Set 15 | mwene-ditu
# Processing Record 44 of Set 15 | vega de alatorre
# Processing Record 45 of Set 15 | fuxin
# Processing Record 46 of Set 15 | jumla
# Processing Record 47 of Set 15 | dwarka
# Processing Record 48 of Set 15 | magistralnyy
# Processing Record 49 of Set 15 | bereda
# Processing Record 50 of Set 15 | krasnyy chikoy
# Processing Record 1 of Set 16 | kathmandu
# Processing Record 2 of Set 16 | meadow lake
# Processing Record 3 of Set 16 | morehead
# Processing Record 4 of Set 16 | tromso
# Processing Record 5 of Set 16 | afrikanda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_database_df = pd.DataFrame(city_data)
city_database_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Flinders -34.5833  150.8552     68.25        94         100
# 1     Carnarvon -24.8667  113.6333     73.47        94          53
# 2         Vaini -21.2000 -175.2000     82.56        83          75
# 3     Busselton -33.6500  115.3333     63.61        80          99
# 4       Baculin   7.4525  126.5842     79.00        86          41
# 5          Bara  10.3744   10.7288     75.43        12           3
# 6    Mandalgovi  45.7625  106.2708     22.59        75          95
# 7  Punta Arenas -53.1500  -70.9167     48.11        75          20
# 8       Mataura -46.1927  168.8643     62.46        69         100
# 9       Qingdao  36.0986  120.3719     44.67        75           4
#
#    Wind Speed Country Current Description
# 0        5.99      AU       moderate rain
# 1       10.36      AU       broken clouds
# 2       13.80      TO       broken clouds
# 3       16.13      AU     overcast clouds
# 4        3.85      PH    scattered clouds
# 5        9.40      NG           clear sky
# 6        8.43      MN     overcast clouds
# 7       11.50      CL          few clouds
# 8        0.98      NZ     overcast clouds
# 9       11.32      CN           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_database_df = city_database_df[new_column_order]
city_database_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Flinders      AU -34.5833  150.8552     68.25        94         100
# 1     Carnarvon      AU -24.8667  113.6333     73.47        94          53
# 2         Vaini      TO -21.2000 -175.2000     82.56        83          75
# 3     Busselton      AU -33.6500  115.3333     63.61        80          99
# 4       Baculin      PH   7.4525  126.5842     79.00        86          41
# 5          Bara      NG  10.3744   10.7288     75.43        12           3
# 6    Mandalgovi      MN  45.7625  106.2708     22.59        75          95
# 7  Punta Arenas      CL -53.1500  -70.9167     48.11        75          20
# 8       Mataura      NZ -46.1927  168.8643     62.46        69         100
# 9       Qingdao      CN  36.0986  120.3719     44.67        75           4
#
#    Wind Speed Current Description
# 0        5.99       moderate rain
# 1       10.36       broken clouds
# 2       13.80       broken clouds
# 3       16.13     overcast clouds
# 4        3.85    scattered clouds
# 5        9.40           clear sky
# 6        8.43     overcast clouds
# 7       11.50          few clouds
# 8        0.98     overcast clouds
# 9       11.32           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_database_df.to_csv(output_data_file, index_label="City_ID")
